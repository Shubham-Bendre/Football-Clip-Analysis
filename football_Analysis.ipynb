# %% [markdown]
# ### **Uploading the Data Set from Universe Roboflow**

# %%
from google.colab import files

# Upload the file
uploaded = files.upload()

# Move the uploaded file to the desired directory
import shutil
shutil.move('best.pt', '/content/football_analysis/models/best.pt')
# Out:
#      <input type="file" id="files-0ccf2b45-eb10-495c-85d0-2abbc0bb8b31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ccf2b45-eb10-495c-85d0-2abbc0bb8b31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **Uploading the Input video**

# %%
from google.colab import files

# Upload the video from your local machine
uploaded = files.upload()

import shutil

# Move the uploaded video to the specific directory
shutil.move('08fd33_4.mp4', '/content/football_analysis/input_videos/08fd33_4.mp4')
# Out:
#      <input type="file" id="files-15c8c2fd-1210-4473-a9d7-ec25dcf1c33c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15c8c2fd-1210-4473-a9d7-ec25dcf1c33c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### **Final Cleansing and Processing with Dataset**

# %%
# !python3 /content/football_analysis/yolo_inference.py
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /content/football_analysis/input_videos/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 4 referees, 1419.3ms
# video 1/1 (frame 2/750) /content/football_analysis/input_videos/08fd33_4.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 4 referees, 1274.2ms
# video 1/1 (frame 3/750) /content/football_analysis/input_videos/08fd33_4.mp4: 384x640 1 goalkeeper, 18 players, 4 referees, 1231.0ms
# ...
